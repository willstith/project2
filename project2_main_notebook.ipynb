# %%
from bs4 import BeautifulSoup
import requests
import time, os
import re

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
#begin at BGG's random game page
randomGameURL = "https://boardgamegeek.com/boardgame/random"
page = requests.get(randomGameURL).text
soup = BeautifulSoup(page,"lxml")

# %%
#unneeded for now due to requests.get().text

#use chromedriver to access ratings page for game and build soup
#driver = webdriver.Chrome(chromedriver)
#driver.get(randomGameURL)
#rating_page = driver.current_url + '/ratings?rated=1'
#driver.get(rating_page)
#soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
num_ratings = driver.find_element_by_xpath("//a[@ui-sref='geekitem.ratings({rated:1})']")
type(num_ratings.text)
# Out:
# str

# %% [markdown]
# I think I'll create a recursive function which calls itself every time the # of ratings is too low, as well as every time it finishes adding a valid game while the number of games added is under 250.

# %%
target_size = 250
board_games_URLS = []

def url_compiler(target_size):
    """Compiles a list of URLs of board games having more than 10 user complexity ratings
        Input: int., desired length of list
        Output: list of urls of length target_size"""
    while len(board_games_URLS) < target_size:
        
        #go to BGG random game and parse its page
        random_Game_URL = "https://boardgamegeek.com/boardgame/random"
        this_game_URL = driver.current_url
        driver = webdriver.Chrome(chromedriver)
        driver.get(randomGameURL)
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        
        #only include games rated at least 10 times (might want to switch to games rated by weight cutoff)
        game_weight = re.search('(?<=\{"averageweight":).{3,50}(?=,"votes":"[0-9]{1,9}")', str(soup)).group(0)
        weight_votes = re.search('(?<=,"votes":")[0-9]{1,9}(?="\}\})', str(soup)).group(0)
        if int(weight_votes) < 10:
            time.sleep(5)
            #add a line <here> to close the browser window 
            url_compiler(target_size)
            
    
        #add the game to the list and collect its data
        else:
            time.sleep(5)
            board_games_URLS.append(this_game_URL)
            url_compiler(target_size)
            
    return board_game_URLS

# %%
def data_extractor(game_url):
    
    driver = webdriver.Chrome(chromedriver)
    driver.get(game_url)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    
    return boardgame_stats_dict

# %%
# def data_extraction_function:

# %%
game_weight = re.search('(?<=\{"averageweight":).{1,50}(?=,"votes":"[0-9]{1,9}")', str(soup)).group(0)
weight_votes = re.search('(?<=,"votes":")[0-9]{1,9}(?="\}\})', str(soup)).group(0)

# %%
print(game_weight, weight_votes)
# Out:
# 0 0

# %%
print(soup.prettify())
# Out:
# <html class="ng-scope" lang="en-US" ng-app="GeekApp">
#  <head>
#   <style type="text/css">
#    [uib-typeahead-popup].dropdown-menu{display:block;}
#   </style>
#   <style type="text/css">
#    .uib-time input{width:50px;}
#   </style>
#   <style type="text/css">
# ...
