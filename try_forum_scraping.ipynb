# %%
from bs4 import BeautifulSoup
import requests
import time, os
import re
import pickle
import xml.etree.ElementTree as ET
import pandas as pd

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chromedriver = "/Applications/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
bg_url = 'https://boardgamegeek.com/boardgame/6209/magblast-second-edition/stats'

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(bg_url)
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <html class="ng-scope" lang="en-US" ng-app="GeekApp">
#  <head>
#   <style type="text/css">
#    [uib-typeahead-popup].dropdown-menu{display:block;}
#   </style>
#   <style type="text/css">
#    .uib-time input{width:50px;}
#   </style>
#   <style type="text/css">
# ...

# %%
gameid, url_name = bg_url.split('/')[4], bg_url.split('/')[5]

# %%
ratings_href = f'/boardgame/{gameid}/{url_name}/ratings?rated=1'

# %%
re.sub("\D", "", soup.find('a', href=plays_href).text)
# Out:
# '1871'

# %%
re.sub("\D", "", soup.find_all('div', class_="outline-item-description ng-binding")[1].text)
# Out:
# '53773'

# %%
res = re.sub("\D", "", soup.find('span', class_="nav-pills-count ng-binding ng-scope").text)

# %%
print(soup.find("div"))

# %%
res
# Out:
# '29'

# %%
plays_href = f'/playstats/thing/{gameid}'

# %%
owners_href = f'/boardgame/{gameid}/{url_name}/ratings?status=own'
re.sub("\D", "", soup.find('a', href=owners_href).text)
# Out:
# '819'

# %%
re.sub("\D", "", soup.find('a', href=plays_href).text)
# Out:
# '1871'

# %%
thisurl = 'https://boardgamegeek.com/boardgame/6209/magblast-second-edition'
x,y = thisurl.split('/')[4], thisurl.split('/')[5]

# %%
x,y
# Out:
# ('6209', 'magblast-second-edition')
